# %% [markdown]
# # SD204 - TP2 : Linear regression

# %% [markdown]
# ### imports

# %%
from scipy.stats import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %% [markdown]
# ### Exercice 1

# %%
df = pd.read_csv("data_tp_2.csv", sep = ",")
df
# Out:
#           X76       X95       X52       X36       X74       X69       X23  \
# 0   -0.208298  0.793446 -0.200865 -0.005766 -0.336092  0.037238  0.148319
# 1   -0.221028 -0.363311 -0.631604  1.152664 -0.532182  1.176513 -0.100142
# 2   -1.059124 -0.777557 -0.172609  0.767116  0.141027  0.677921  0.820292
# 3    1.133450 -0.790638 -0.586627  0.942378  0.283674 -0.577118 -0.145977
# 4    0.908181 -0.913293  0.362265 -0.437131  0.514517 -1.625222  1.019997
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.608114  0.938399  0.051940 -0.972496 -0.455969  0.160660 -0.818642
# 502 -0.154366  0.324157 -0.382372 -0.085913 -0.315436 -0.505230  0.396888
# 503 -0.334168  0.902759  0.845292  0.474392 -0.329404 -0.020669  0.298615
# 504  0.833393 -0.809250 -0.548674  0.047740  0.528402 -0.074027  0.643996
# 505 -0.212957  0.052388  0.363013 -0.481527 -0.237502  0.451631 -0.848306
#
#           X27       X19       X39  ...       X45       X67       X16  \
# 0   -1.423624 -0.411594  0.541975  ... -0.216825  0.552672  0.499400
# 1    1.170051  0.360931  0.593115  ...  0.571930 -0.186832 -0.238081
# 2   -0.255193  0.691621  0.254366  ... -0.643929 -0.543850 -0.478493
# 3   -0.263209  1.435926 -0.750034  ...  0.719154  0.056236 -0.495367
# 4   -0.422887  0.140903 -0.073760  ...  1.026587 -0.230706  0.151710
# ..        ...       ...       ...  ...       ...       ...       ...
# 501 -0.483332 -0.311482  0.723593  ...  0.172286  0.162128  0.447561
# 502  1.190629 -0.072879 -0.155551  ...  1.579612 -0.196807  0.942472
# 503 -0.151245  0.163579 -0.174481  ...  0.473958  0.671534 -0.103124
# 504  1.077708 -0.342874  0.791408  ... -1.153192  1.039399  0.384485
# 505  0.694463  2.328985 -0.000448  ... -0.361958 -0.218380  0.771737
#
#           X37       X56       X35       X87       X89       X96     Y
# 0    0.134669 -1.639742 -0.004640 -0.635006 -0.758949  0.488324  24.0
# 1    1.404931  0.489104  0.248675  0.361039  0.435418 -1.324025  21.6
# 2   -0.386637  0.175114 -0.658092 -0.338583 -0.177981 -0.050339  34.7
# 3    0.204324 -1.078683  0.640999 -0.921276 -0.602238  0.421393  33.4
# 4   -0.638937  0.072631 -0.517829 -1.028707  0.465484  0.351005  36.2
# ..        ...       ...       ...       ...       ...       ...   ...
# 501  0.392702  0.098069  0.886292  0.070858  0.032393  0.340219  22.4
# 502 -0.603286 -0.618815 -0.348162  0.743787  0.443682  0.201446  20.6
# 503  0.867858  0.105762 -0.561985  0.891691  0.439631  0.432772  23.9
# 504  0.035854  0.654475 -0.034259 -0.853840  0.649302  0.051112  22.0
# 505  1.262447  0.281434 -0.673687  1.398793  0.710843 -1.507099  11.9
#
# [506 rows x 101 columns]

# %%
covariates = df[df.columns[0:df.shape[1]-1]]
scores = df[df.columns[-1]]
median = covariates.median()
std = covariates.std()

figure = plt.figure(figsize=(15,4))
axes = figure.add_subplot(111)
axes.set_xlabel('covariates')
axes.xaxis.set_ticks(range(len(covariates.columns)))
axes.xaxis.set_ticklabels(list(covariates.columns))
axes.scatter(covariates.columns, median, s=10, c='b', marker="s", label='median')
axes.scatter(covariates.columns, std, s=10, c='r', marker="o", label='std')
plt.legend(loc='upper left')
plt.title("Median and Std of data")
plt.show()

# %%
median = covariates.median()

print(median)
# Out:
# X76   -0.039929
# X95   -0.050345
# X52   -0.011161
# X36    0.020448
# X74    0.067290
#          ...
# X56   -0.029397
# X35    0.041134
# X87   -0.004115
# X89   -0.052846
# X96    0.022785
# Length: 100, dtype: float64

# %% [markdown]
# The dataframe is

# %%
X_train, X_test, Y_train, Y_test = train_test_split(covariates, scores, test_size = 0.25)

print("Train sample :", X_train.shape)
print("Test sample :", X_test.shape)
# Out:
# Train sample : (379, 100)
# Test sample : (127, 100)

# %%
#data = pd.concat([X_train,X_test],ignore_index=True)

scaled_features_train = StandardScaler().fit_transform(X_train.values)
X_train_s = pd.DataFrame(scaled_features_train, index=X_train.index, columns=X_train.columns)

scaled_features_test = StandardScaler().fit_transform(X_test.values)
X_test_s = pd.DataFrame(scaled_features_test, index=X_test.index, columns=X_test.columns)

scaled_covariates = pd.concat([X_train_s,X_test_s],ignore_index=True)

# %%
median = scaled_covariates.median()
std = scaled_covariates.std()

figure = plt.figure(figsize=(15,4))
axes = figure.add_subplot(111)
axes.set_xlabel('covariates')
axes.xaxis.set_ticks(range(len(scaled_covariates.columns)))
axes.xaxis.set_ticklabels(list(scaled_covariates.columns))
axes.scatter(scaled_covariates.columns, median, s=10, c='b', marker="s", label='median')
axes.scatter(scaled_covariates.columns, std, s=10, c='r', marker="o", label='std')
plt.legend(loc='upper left')
plt.title("Median and Std of data")
plt.show()

# %%
scaled_df = pd.concat([scaled_covariates, scores], axis=1)
scaled_df
# Out:
#           X76       X95       X52       X36       X74       X69       X23  \
# 0    0.656659  0.143133  0.218578 -1.512174 -0.741358  0.527808  1.773116
# 1   -0.529798  0.303472 -0.375802  0.533971  0.076470  0.378327  1.338951
# 2   -0.968237  1.519897  0.148600 -0.906241 -0.969344  2.194241 -0.815432
# 3    0.512858 -1.150729  1.675199 -0.198474 -1.118522 -0.475619  1.812480
# 4   -0.111662  0.797016  1.138886  0.480152  1.838431 -1.490344 -0.198343
# ..        ...       ...       ...       ...       ...       ...       ...
# 501  1.197351  0.357744  0.359792  0.343806 -1.531027  0.777909  0.289380
# 502 -0.792555 -0.496429 -1.083269 -0.298076 -1.281600  1.962779  0.280839
# 503  0.720559  0.955914  0.256420 -1.268482  0.024305 -1.402062 -1.181348
# 504 -1.847519  0.860347 -0.465814 -0.320097  0.524641  0.801645 -0.415848
# 505  0.130918  1.201092 -2.161932 -1.146702 -0.298735  1.475794 -0.613397
#
#           X27       X19       X39  ...       X45       X67       X16  \
# 0   -0.653114 -0.818397 -1.303134  ...  0.270590  0.547817  0.549563
# 1   -1.782197  0.346178 -0.382472  ...  0.289854  2.075108  0.741073
# 2   -0.533190 -0.465611  0.136296  ... -0.060163  0.398292  1.097355
# 3    0.095274 -0.638553  0.207695  ... -0.519610 -0.967274 -2.480576
# 4    0.735482 -0.840178 -1.187960  ... -0.213971 -0.330446  1.722524
# ..        ...       ...       ...  ...       ...       ...       ...
# 501 -0.907816  0.569764 -1.829007  ...  0.042471 -0.185581 -0.387472
# 502 -0.767793 -0.695931 -0.629937  ...  0.566882 -0.166198 -0.387509
# 503 -0.488592  0.114597 -1.919919  ... -1.693427  0.813249 -0.720795
# 504  0.719071 -0.487511 -0.282305  ...  0.533888 -1.126776 -0.231117
# 505  0.311092  1.042687  0.445171  ... -0.607827 -0.101189  0.537402
#
#           X37       X56       X35       X87       X89       X96     Y
# 0   -1.331569  0.607544  0.632476  0.566626  0.372138 -0.607409  24.0
# 1    0.501117 -1.316783 -1.103582  1.401679  0.400384 -0.621638  21.6
# 2    0.226716 -0.442861  0.811671  0.317479 -1.369255  1.717751  34.7
# 3   -1.637269  0.090759  0.019380 -1.983350 -1.063553  0.371020  33.4
# 4    1.232364  0.098618  0.082876 -1.562330  0.965198 -1.312842  36.2
# ..        ...       ...       ...       ...       ...       ...   ...
# 501 -0.557192 -1.265286 -0.415254  0.079357 -0.701361  1.690883  22.4
# 502 -1.024387  0.650100 -0.627459  0.491710 -0.638981  0.090372  20.6
# 503  0.288090 -1.754043 -0.875067 -2.127160  0.093176 -0.169703  23.9
# 504  0.014811 -2.327162 -0.174557 -0.158160  0.173536  0.526336  22.0
# 505  1.086442  0.740266  0.780689  0.208749  0.700264  0.222194  11.9
#
# [506 rows x 101 columns]

# %% [markdown]
# Lassoooo

# %%
df_test = pd.DataFrame()
df_coef = pd.DataFrame()

# %%
def mse(y, y_pred):
    error = y - y_pred 
    se = np.sum(error**2) 
    mse = se/len(y)  
    return round(mse,3)

def R2(y, y_pred):
    error = y - y_pred 
    se = np.sum(error**2) 
    SSt = np.sum((y - np.mean(y))**2) 
    R2 = 1- (se/SSt) 
    return round(R2,3)

# %%
ols = LinearRegression().fit(X_train_s, Y_train)
Y_pred = ols.predict(X_test_s)
coef = ols.coef_
plt.show()

print("mse =", mse(Y_test, Y_pred))
print("R2 =", R2(Y_test, Y_pred))

df_test["OLS"] = Y_pred
df_coef["OLS"] = coef
# Out:
# mse = 25.66
# R2 = 0.671

# %%
df_coef
# Out:
#          OLS
# 0  -0.143759
# 1  -0.287578
# 2   0.118977
# 3  -0.083924
# 4  -0.447242
# ..       ...
# 95  0.126482
# 96 -0.102471
# 97 -0.076289
# 98 -0.190866
# 99 -0.531692
#
# [100 rows x 1 columns]

# %%
sns.heatmap(scaled_covariates.cov())

# %%
U,s,V  = np.linalg.svd(scaled_covariates, full_matrices=True)
U.shape, s.shape, V.shape
# Out:
# ((506, 506), (100,), (100, 100))

# %%
"""print(U[:, :1].shape)
PC1 = (U[:, :1]*s)[0]
PC2 = (U[:, :1]*s)[1]
print(PC1.shape, PC2.shape)

plt.figure(figsize=(10,10))
plt.scatter(PC1,PC2)
plt.title("PCA")
plt.xlabel('PC1')
plt.ylabel('PC2')"""

U,s,V  = np.linalg.svd(scaled_covariates.cov(), full_matrices=True)
PCs = U@np.diag(s)
PC1=PCs[:,0]
PC2=PCs[:,1]
plt.scatter(PC1,PC2)

# %%
X_train_pca = X_train_s * U[:,2]
ols = LinearRegression().fit(X_train_pca, Y_train)

X_test_pca = X_test_s * U[:,2]
Y_pred_pca = ols.predict(X_test_pca)

print(X_test_s.shape)
print(X_train_s.shape)
print(Y_train.shape)
print(Y_test.shape)

print(X_test_pca.shape)
print(X_train_pca.shape)


coef_pca = ols.coef_
plt.show()

print("mse =", mse(Y_train, Y_pred_pca))
print("R2 =", R2(Y_train, Y_pred_pca))

df_test["pca_OLS"] = Y_pred_pca
df_coef["pca_OLS"] = coef_pca
# Out:
# (127, 100)
# (379, 100)
# (379,)
# (127,)
# (127, 100)
# (379, 100)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-43a575c75d9a> in <module>
#      17 plt.show()
#      18
# ---> 19 print("mse =", mse(Y_train, Y_pred_pca))
#      20 print("R2 =", R2(Y_train, Y_pred_pca))
#      21
#
# <ipython-input-16-a8087514a32a> in mse(y, y_pred)
#       1 def mse(y, y_pred):
# ----> 2     error = y - y_pred
#       3     se = np.sum(error**2)
#       4     mse = se/len(y)
#       5     return round(mse,3)
#
# c:\users\remij\miniconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#    1046
#    1047         with np.errstate(all="ignore"):
# -> 1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
#    1050             left, result, index=left.index, name=res_name, dtype=None
#
# c:\users\remij\miniconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#     966
#     967         try:
# --> 968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
#     970             result = masked_arith_op(x, y, op)
#
# c:\users\remij\miniconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     219     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#     223
#
# c:\users\remij\miniconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      68         _store_test_result(False)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#      72
#
# ValueError: operands could not be broadcast together with shapes (379,) (127,)

# %%
a = np.random.randn(5, 4)
u, s, vh = np.linalg.svd(a, full_matrices=True)
print(a, "\n")
print(u.shape, s.shape, vh.shape)
print(u, s, vh)

print(np.allclose(a, np.dot(u[:, :6] * s, vh)))
# Out:
# [[ 0.23085442  1.57407094  1.08368338 -0.55335687]
#  [-1.55627566  0.60611348 -0.71978469 -2.95617562]
#  [ 0.9884104   0.66966318  1.75820763 -1.02108501]
#  [-0.70696604 -1.27252361 -1.24430656  0.12178481]
#  [ 0.31010637  1.5248494   0.87071725 -0.46879903]]
#
# (5, 5) (4,) (4, 4)
# [[-0.48745585  0.10797868  0.37664792 -0.76092559  0.17278887]
#  [-0.35251876 -0.92372343 -0.03876726  0.04425306 -0.13785611]
#  [-0.5189679   0.20515412 -0.80988935  0.00172132  0.18072184]
#  [ 0.41677346 -0.28521022 -0.15544508 -0.19687227  0.82585298]
#  [-0.44168939  0.10790059  0.42017796  0.61666219  0.48625731]] [3.93043125 3.44466374 1.17088838 0.11761666] [[-0.12937095 -0.64429419 -0.53178491  0.53418438]
#  [ 0.55168425  0.07981561  0.46200158  0.68980323]
#  [-0.35274535  0.73921286 -0.36605107  0.44174844]
#  [ 0.74463304  0.17910558 -0.60808385 -0.2089901 ]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-cea8117a0e3b> in <module>
#       5 print(u, s, vh)
#       6
# ----> 7 print(np.allclose(a, np.dot(u[:, :6] * s, vh)))
#
# ValueError: operands could not be broadcast together with shapes (5,5) (4,)
